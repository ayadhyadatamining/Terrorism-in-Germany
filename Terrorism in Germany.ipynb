# %%
url ='https://en.wikipedia.org/wiki/Terrorism_in_Germany#List_of_significant_terrorist_incidents_in_Germany'

# %%
import os

# %%
os.chdir('D:\\scripting')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %%
browser=webdriver.Firefox()

# %%
browser.get(url)

# %%
html=browser.page_source
html
# Out:
# '<html class="client-js ve-available" dir="ltr" lang="en"><head>\n<meta charset="UTF-8">\n<title>Terrorism in Germany - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"cdd5d43a-7702-4beb-915c-70ae5c571f45","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Terrorism_in_Germany","wgTitle":"Terrorism in Germany","wgCurRevisionId":1059768774,"wgRevisionId":1059768774,"wgArticleId":35484188,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","Articles with short description","Short description is different from Wikidata","Use dmy dates fr
# ...

# %%
soup=BeautifulSoup(html,'html.parser')

# %%
print(soup)
# Out:
# <html class="client-js ve-available" dir="ltr" lang="en"><head>
# <meta charset="utf-8"/>
# <title>Terrorism in Germany - Wikipedia</title>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.select("table.wikitable.sortable.collapsible.mw-collapsible.mw-made-collapsible.jquery-tablesorter")
# Out:
# [<table class="wikitable sortable collapsible collapsed floatright mw-collapsible mw-collapsed mw-made-collapsible jquery-tablesorter" style="text-align:right">
#  <caption class="nowrap">Terrorist incidents in Germany<sup class="reference" id="cite_ref-globalterrorismdb_0616dist_1-0"><a href="#cite_note-globalterrorismdb_0616dist-1">[1]</a></sup><sup class="reference" id="cite_ref-gtd1993_0616dist_2-0"><a href="#cite_note-gtd1993_0616dist-2">[2]</a></sup>
#  <span aria-expanded="false" class="mw-collapsible-toggle mw-collapsible-toggle-default mw-collapsible-toggle-collapsed" role="button" tabindex="0"><a class="mw-collapsible-text">show</a></span></caption>
#  <thead><tr style="background: rgb(236, 236, 236) none repeat scroll 0% 0%; vertical-align: top; display: none;">
#  <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Year</th>
#  <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Incidents</th>
# ...

# %%
table2=soup.select("table.wikitable.sortable.collapsible.mw-collapsible.mw-made-collapsible.jquery-tablesorter")[1]

# %%
table2.find_all('th')
# Out:
# [<th colspan="8"><span aria-expanded="true" class="mw-collapsible-toggle mw-collapsible-toggle-default" role="button" tabindex="0"><a class="mw-collapsible-text">hide</a></span><big>Germany</big>
#  </th>,
#  <th class="headerSort" role="columnheader button" style="width:11%;" tabindex="0" title="Sort ascending"><small>Date</small>
#  </th>,
#  <th class="headerSort" role="columnheader button" style="width:6%;" tabindex="0" title="Sort ascending"><small>Sub</small>
#  </th>,
#  <th class="headerSort" role="columnheader button" style="width:10%;" tabindex="0" title="Sort ascending"><small>Location</small>
#  </th>,
#  <th class="headerSort" role="columnheader button" style="width:6%;" tabindex="0" title="Sort ascending"><small>Deaths</small>
#  </th>,
#  <th class="headerSort" role="columnheader button" style="width:6%;" tabindex="0" title="Sort ascending"><small>Injuries</small>
#  </th>,
# ...

# %%
table2.find_all("th")[1].text.strip()
# Out:
# 'Date'

# %%
theads = []
for i in range(1,len(table2.find_all("th"))):
    theads.append(table2.find_all("th")[i].text.strip())
theads
# Out:
# ['Date',
#  'Sub',
#  'Location',
#  'Deaths',
#  'Injuries',
#  'Type',
#  'Perpetrator or motives',
#  'Description']

# %%
body = []
for r in table2.tbody.find_all("tr"):
    body.append([i.text.strip() for i in r.find_all("td")])
body
# Out:
# [['2 April 1968',
#   '',
#   'Frankfurt',
#   '0—',
#   '0—',
#   'Arson',
#   'Red Army Faction',
#   '-- Shopping Mall\nTwo founding fathers of the RAF, Andreas Baader and Gudrun Ensslin, set fire to a shopping mall in Frankfurt as a political statement against capitalism.[12]'],
#  ['11 April 1968',
#   '',
#   'Berlin',
#   '0—',
#   '1',
#   'Small arms fire',
#   'Neo-Nazi Josef Bachmann',
#   '-- Rudi Dutschke, prominent figure of the left-wing students movement\n23 year old Neo-Nazi Josef Bachmann tried to assassinate the prominent left-wing figure Rudi Dutschke by firing multiple shots at him. The victim was seriously wounded and scarred for life.[13]'],
#  ['10 February 1970',
#   '',
#   'Munich',
#   '1',
#   '23',
#   'Grenade attack and Small arms fire',
#   'PDFLP (Palestinian nationalists)',
# ...

# %%
len(body)
# Out:
# 69

# %%
len(theads)
# Out:
# 8

# %%
for i in body:
    print(len(i))
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8

# %%
len(body[-16])
# Out:
# 9

# %%
body[-16] = body[-16][:-1]

# %%
body[-16]
# Out:
# ['28 July 2017',
#  '',
#  'Hamburg',
#  '1',
#  '6',
#  'Stabbing',
#  'Ahmad Alhaw (Islamic State)',
#  '-- Private Citizens \nMain article: 2017 Hamburg attack']

# %%
df2 = pd.DataFrame(body, columns=theads)
df2
# Out:
#                  Date Sub        Location          Deaths Injuries  \
# 0        2 April 1968           Frankfurt              0—       0—
# 1       11 April 1968              Berlin              0—        1
# 2    10 February 1970              Munich               1       23
# 3    13 February 1970              Munich               7       10
# 4     2 February 1972              Berlin               1       0—
# ..                ...  ..             ...             ...      ...
# 64   19 February 2020               Hanau  11 (one perp.)        5
# 65     18 August 2020              Berlin               —        6
# 66     4 October 2020             Dresden               1        1
# 67        26 May 2021              Berlin               —        —
# 68  18 September 2021      Idar-Oberstein               1        —
#
#                                   Type  \
# 0                                Arson
# 1                      Small arms fire
# 2   Grenade attack and Small arms fire
# ...

# %%
def wiki_table():
    thead = [i.text.strip() for i in table2.find_all('th')]
    data=[]
    for r in soup.select('table.wikitable.sortable.collapsible.mw-collapsible.mw-made-collapsible.jquery-tablesorter')[1].tbody.find_all('tr'):
        data.append([i.text.strip() for i in r.find_all('td')])
    df2 = pd.DataFrame(body)
    df2.columns= theads
    return df2

# %%
wiki_table()
# Out:
#                  Date Sub        Location          Deaths Injuries  \
# 0        2 April 1968           Frankfurt              0—       0—
# 1       11 April 1968              Berlin              0—        1
# 2    10 February 1970              Munich               1       23
# 3    13 February 1970              Munich               7       10
# 4     2 February 1972              Berlin               1       0—
# ..                ...  ..             ...             ...      ...
# 64   19 February 2020               Hanau  11 (one perp.)        5
# 65     18 August 2020              Berlin               —        6
# 66     4 October 2020             Dresden               1        1
# 67        26 May 2021              Berlin               —        —
# 68  18 September 2021      Idar-Oberstein               1        —
#
#                                   Type  \
# 0                                Arson
# 1                      Small arms fire
# 2   Grenade attack and Small arms fire
# ...

# %%
df2.shape
# Out:
# (69, 8)

# %%
df2["Date"]
# Out:
# 0          2 April 1968
# 1         11 April 1968
# 2      10 February 1970
# 3      13 February 1970
# 4       2 February 1972
#             ...
# 64     19 February 2020
# 65       18 August 2020
# 66       4 October 2020
# 67          26 May 2021
# 68    18 September 2021
# Name: Date, Length: 69, dtype: object

# %%
df2.to_csv("Terrorism_in_Germany1.csv")

# %%
pd.read_csv("Terrorism_in_Germany1.csv").head()
# Out:
#    Unnamed: 0              Date  Sub   Location Deaths Injuries  \
# 0           0      2 April 1968  NaN  Frankfurt     0—       0—
# 1           1     11 April 1968  NaN     Berlin     0—        1
# 2           2  10 February 1970  NaN     Munich      1       23
# 3           3  13 February 1970  NaN     Munich      7       10
# 4           4   2 February 1972  NaN     Berlin      1       0—
#
#                                  Type            Perpetrator or motives  \
# 0                               Arson                  Red Army Faction
# 1                     Small arms fire           Neo-Nazi Josef Bachmann
# 2  Grenade attack and Small arms fire  PDFLP (Palestinian nationalists)
# 3                               Arson       Anarchist group (suspected)
# 4                         Bomb attack                   2 June Movement
#
#                                          Description
# 0  -- Shopping Mall\nTwo founding fathers of the ...
# ...
